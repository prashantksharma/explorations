# %% [markdown]
# <a href="https://colab.research.google.com/github/prashantksharma/explorations/blob/main/twitter_scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install snscrape
# Out:
# Collecting snscrape
#   Downloading snscrape-0.7.0.20230622-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.8/74.8 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from snscrape) (2.31.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.9.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from snscrape) (4.11.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from snscrape) (3.12.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->snscrape) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->snscrape) (1.7.1)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.7.0.20230622

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as snstwitter

# %% [markdown]
# # Twitter Data

# %%
profile = 'rpoo'

# %%
userScraper = snstwitter.TwitterProfileScraper(profile)

# %%
userdata = userScraper.entity

print(f"Scraping {profile}")

for i, tweet in enumerate(userScraper.get_items()):
    print(f"#{i+1} of {userdata.statusesCount} on ({tweet.date.strftime('%Y-%m-%d %H:%M')}): {tweet.url}")

print("Done!")
# Out:
# Scraping rpoo
# ERROR:snscrape.base:Error retrieving https://twitter.com/i/api/graphql/fn9oRltM1N4thkh5CVusPg/UserTweetsAndReplies?variables=%7B%22userId%22%3A314341900%2C%22count%22%3A100%2C%22includePromotedContent%22%3Atrue%2C%22withCommunity%22%3Atrue%2C%22withVoice%22%3Atrue%2C%22withV2Timeline%22%3Atrue%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Atrue%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Atrue%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Atrue%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%7D: blocked (404)
# CRITICAL:snscrape.base:4 requests to https://twitter.com/i/api/graphql/fn9oRltM1N4thkh5CVusPg/UserTweetsAndReplies?variables=%7B%22userId%22%3A314341900%2C%22count%22%3A100%2C%22includePromotedContent%22%3Atrue%2C%22withCommunity%22%3Atrue%2C%22withVoice%22%3Atrue%2C%22withV2Timeline%22%3Atrue%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Atrue%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Atrue%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Atrue%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%7D failed, giving up.
# CRITICAL:snscrape.base:Errors: blocked (404), blocked (404), blocked (404), blocked (404)
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-14-ff7b840b7004> in <cell line: 5>()
#       3 print(f"Scraping {profile}")
#       4
# ----> 5 for i, tweet in enumerate(userScraper.get_items()):
#       6     print(f"#{i+1} of {userdata.statusesCount} on ({tweet.date.strftime('%Y-%m-%d %H:%M')}): {tweet.url}")
#       7
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in get_items(self)
#    1895                 gotPinned = False
#    1896                 previousPagesTweetIds = set()
# -> 1897                 for obj in self._iter_api_data('https://twitter.com/i/api/graphql/fn9oRltM1N4thkh5CVusPg/UserTweetsAndReplies', _TwitterAPIType.GRAPHQL, params, paginationParams, instructionsPath = ['data', 'user', 'result', 'timeline_v2', 'timeline', 'instructions']):
#    1898                         if not obj['data'] or 'result' not in obj['data']['user']:
#    1899                                 raise snscrape.base.ScraperException('Empty response')
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction, instructionsPath)
#     913                 while True:
#     914                         _logger.info(f'Retrieving scroll page {cursor}')
# --> 915                         obj = self._get_api_data(endpoint, apiType, reqParams, instructionsPath = instructionsPath)
#     916                         yield obj
#     917
#
# /usr/local/lib/python3.10/dist-packages/snscrape/modules/twitter.py in _get_api_data(self, endpoint, apiType, params, instructionsPath)
#     884                 if apiType is _TwitterAPIType.GRAPHQL:
#     885                         params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 886                 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = functools.partial(self._check_api_response, apiType = apiType, instructionsPath = instructionsPath))
#     887                 return r._snscrapeObj
#     888
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _get(self, *args, **kwargs)
#     273
#     274         def _get(self, *args, **kwargs):
# --> 275                 return self._request('GET', *args, **kwargs)
#     276
#     277         def _post(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/snscrape/base.py in _request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     269                         _logger.fatal(msg)
#     270                         _logger.fatal(f'Errors: {", ".join(errors)}')
# --> 271                         raise ScraperException(msg)
#     272                 raise RuntimeError('Reached unreachable code')
#     273
#
# ScraperException: 4 requests to https://twitter.com/i/api/graphql/fn9oRltM1N4thkh5CVusPg/UserTweetsAndReplies?variables=%7B%22userId%22%3A314341900%2C%22count%22%3A100%2C%22includePromotedContent%22%3Atrue%2C%22withCommunity%22%3Atrue%2C%22withVoice%22%3Atrue%2C%22withV2Timeline%22%3Atrue%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Atrue%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Atrue%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Atrue%2C%22longform_notetweets_inline_media_e...

# %%
# !pip install twscrape
# Out:
# Collecting twscrape
#   Downloading twscrape-0.8.0-py3-none-any.whl (28 kB)
# Collecting aiosqlite==0.17.0 (from twscrape)
#   Downloading aiosqlite-0.17.0-py3-none-any.whl (15 kB)
# Collecting fake-useragent==1.2.1 (from twscrape)
#   Downloading fake_useragent-1.2.1-py3-none-any.whl (14 kB)
# Collecting httpx==0.24.0 (from twscrape)
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 6.1 MB/s eta 0:00:00
# Collecting loguru==0.7.0 (from twscrape)
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from aiosqlite==0.17.0->twscrape) (4.5.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->twscrape) (2023.7.22)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.0->twscrape)
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->twscrape) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.24.0->twscrape) (1.3.0)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx==0.24.0->twscrape)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.0->twscrape) (3.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx==0.24.0->twscrape) (1.1.3)
# Installing collected packages: fake-useragent, loguru, h11, aiosqlite, httpcore, httpx, twscrape
# Successfully installed aiosqlite-0.17.0 fake-useragent-1.2.1 h11-0.14.0 httpcore-0.17.3 httpx-0.24.0 loguru-0.7.0 twscrape-0.8.0

# %%
# !pip install parsel
# Out:
# Collecting parsel
#   Downloading parsel-1.8.1-py2.py3-none-any.whl (17 kB)
# Collecting cssselect>=0.9 (from parsel)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Collecting jmespath (from parsel)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from parsel) (4.9.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from parsel) (23.1)
# Collecting w3lib>=1.19.0 (from parsel)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Installing collected packages: w3lib, jmespath, cssselect, parsel
# Successfully installed cssselect-1.2.0 jmespath-1.0.1 parsel-1.8.1 w3lib-2.1.2

# %%
import json
import httpx
from parsel import Selector

# %%
# !pip install httpx[http2]
# Out:
# Requirement already satisfied: httpx[http2] in /usr/local/lib/python3.10/dist-packages (0.24.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx[http2]) (2023.7.22)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from httpx[http2]) (0.17.3)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx[http2]) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx[http2]) (1.3.0)
# Collecting h2<5,>=3 (from httpx[http2])
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.8 MB/s eta 0:00:00
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2])
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2])
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx[http2]) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx[http2]) (3.7.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx[http2]) (1.1.3)
# Installing collected packages: hyperframe, hpack, h2
# Successfully installed h2-4.1.0 hpack-4.0.0 hyperframe-6.0.1

# %%
import json
import httpx
from parsel import Selector

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.54 Safari/537.36",
    "Accept-Encoding": "gzip, deflate, br",
    "Accept-Language": "en-US,en;q=0.9",
}


# retrieve embed HTML
with httpx.Client(http2=True, headers=HEADERS) as client:
    response = client.get(
        "https://syndication.twitter.com/srv/timeline-profile/screen-name/rpoo"
    )
    assert response.status_code == 200
sel = Selector(response.text)
# find data cache:
data = json.loads(sel.css("script#__NEXT_DATA__::text").get())
# parse tweet data from data cache JSON:
tweet_data = data["props"]["pageProps"]["timeline"]["entries"]
tweets = [tweet["content"]["tweet"] for tweet in tweet_data]
print(tweets)
# Out:
# [{'id': 0, 'location': '', 'conversation_id_str': '1652225376733773824', 'created_at': 'Sat Apr 29 08:16:41 +0000 2023', 'display_text_range': [0, 279], 'entities': {'user_mentions': [], 'urls': [], 'hashtags': [], 'symbols': [], 'media': [{'display_url': 'pic.twitter.com/KwiOP0i6gD', 'expanded_url': 'https://twitter.com/rpoo/status/1652225376733773824/photo/1', 'id_str': '1652222789359910912', 'indices': [280, 303], 'media_key': '3_1652222789359910912', 'media_url_https': 'https://pbs.twimg.com/media/Fu3f34GaQAAUq2y.png', 'type': 'photo', 'url': 'https://t.co/KwiOP0i6gD', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces': []}, 'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}}, 'sizes': {'large': {'h': 463, 'w': 850, 'resize': 'fit'}, 'medium': {'h': 463, 'w': 850, 'resize': 'fit'}, 'small': {'h': 370, 'w': 680, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 463, 'width': 850, 'focus_rects': [{'x': 23, 'y': 0, 'w': 827, 'h': 463}, {'x': 387, 'y': 0, 'w': 463, 'h': 463}, {'x': 444, 'y': 0, 'w': 406, 'h': 463}, {'x': 618, 'y': 0, 'w': 232, 'h': 463}, {'x': 0, 'y': 0, 'w': 850, 'h': 463}]}}]}, 'extended_entities': {'media': [{'display_url': 'pic.twitter.com/KwiOP0i6gD', 'expanded_url': 'https://twitter.com/rpoo/status/1652225376733773824/photo/1', 'id_str': '1652222789359910912', 'indices': [280, 303], 'media_key': '3_1652222789359910912', 'media_url_https': 'https://pbs.twimg.com/media/Fu3f34GaQAAUq2y.png', 'type': 'photo', 'url': 'https://t.co/KwiOP0i6gD', 'ext_media_availability': {'status': 'Available'}, 'features': {'large': {'faces': []}, 'medium': {'faces': []}, 'small': {'faces': []}, 'orig': {'faces': []}}, 'sizes': {'large': {'h': 463, 'w': 850, 'resize': 'fit'}, 'medium': {'h': 463, 'w': 850, 'resize': 'fit'}, 'small': {'h': 370, 'w': 680, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}, 'original_info': {'height': 463, 'width': 850, 'focus_rects': [{'x': 23, 'y': 0, 'w': 827, 'h': 463}, {'x': 387, 'y': 0, 'w': 463, 'h': 463}, {'x': 444, 'y': 0, 'w': 406, 'h': 463}, {'x': 618, 'y': 0, 'w': 232, 'h': 463}, {'x': 0, 'y': 0, 'w': 850, 'h': 463}]}}]}, 'favorite_count': 3827, 'favorited': False, 'full_text': 'People keep saying we\'re "running out of water"\n\nSome notes\n* earth\'s total water supply is basically constant \n* water is constantly changing form (liquid, evaporate to gas, freeze to solid, back to liquid, etc) and location (sea to mountains to rivers to aquifers to fields)\n*… https://t.co/KwiOP0i6gD', 'id_str': '1652225376733773824', 'lang': 'en', 'permalink': '/rpoo/status/1652225376733773824', 'possibly_sensitive': False, 'quote_count': 81, 'reply_count': 352, 'retweet_count': 546, 'retweeted': False, 'text': 'People keep saying we\'re "running out of water"\n\nSome notes\n* earth\'s total water supply is basically constant \n* water is constantly changing form (liquid, evaporate to gas, freeze to solid, back to liquid, etc) and location (sea to mountains to rivers to aquifers to fields)\n*… https://t.co/KwiOP0i6gD', 'user': {'blocking': False, 'created_at': 'Fri Jun 10 03:04:39 +0000 2011', 'default_profile': True, 'default_profile_image': False, 'description': '', 'entities': {'description': {'urls': []}, 'url': {}}, 'fast_followers_count': 0, 'favourites_count': 1222, 'follow_request_sent': False, 'followed_by': False, 'followers_count': 15623, 'following': False, 'friends_count': 913, 'has_custom_timelines': False, 'highlightedLabel': {'badge': {'url': 'https://pbs.twimg.com/profile_images/1696361350849789953/y5d3GaZX_bigger.jpg'}, 'description': 'xAI', 'userLabelType': 'BusinessLabel', 'userLabelDisplayType': 'Badge'}, 'id': 0, 'id_str': '314341900', 'is_translator': False, 'listed_count': 191, 'location': 'San Francisco, CA', 'media_count': 67, 'name': 'Ross', 'normal_followers_count': 15623, 'notifications': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31434 ...

# %%
type(tweets)
# Out:
# list

# %%
len(tweets)
# Out:
# 100

# %%
import pandas as pd

# %%
df = pd.DataFrame(tweets)
df
# Out:
#     id location  conversation_id_str                      created_at  \
# 0    0           1652225376733773824  Sat Apr 29 08:16:41 +0000 2023
# 1    0           1649824168828092416  Sat Apr 22 17:15:08 +0000 2023
# 2    0           1649513815527096320  Fri Apr 21 20:41:54 +0000 2023
# 3    0           1670500718220910594  Sun Jun 18 18:36:22 +0000 2023
# 4    0           1679143101288570881  Wed Jul 12 14:58:06 +0000 2023
# ..  ..      ...                  ...                             ...
# 95   0           1649064613873426435  Thu Apr 20 14:56:56 +0000 2023
# 96   0           1682043848309211137  Thu Jul 20 15:11:16 +0000 2023
# 97   0           1652225376733773824  Sat Apr 29 21:05:47 +0000 2023
# 98   0           1662963345769787392  Sun May 28 23:25:32 +0000 2023
# 99   0           1673020639786192898  Sun Jun 25 17:29:38 +0000 2023
#
#    display_text_range                                           entities  \
# 0            [0, 279]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 1            [0, 281]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 2            [0, 281]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 3             [0, 37]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 4             [0, 51]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# ..                ...                                                ...
# 95             [0, 9]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 96           [0, 209]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 97          [15, 282]  {'user_mentions': [{'id_str': '1936176655', 'n...
# 98           [0, 282]  {'user_mentions': [], 'urls': [], 'hashtags': ...
# 99            [0, 57]  {'user_mentions': [], 'urls': [], 'hashtags': ...
#
#                                     extended_entities  favorite_count  \
# 0   {'media': [{'display_url': 'pic.twitter.com/Kw...            3827
# 1                                                 NaN            3452
# 2                                                 NaN            1509
# 3                                                 NaN            1244
# 4                                                 NaN            1256
# ..                                                ...             ...
# 95  {'media': [{'display_url': 'pic.twitter.com/A4...              66
# 96                                                NaN              68
# 97                                                NaN              68
# 98                                                NaN              64
# 99                                                NaN              64
#
#     favorited                                          full_text  ...  \
# 0       False  People keep saying we're "running out of water...  ...
# 1       False  20% of Twitter users make up 100% of the conte...  ...
# 2       False  What a time to be alive!  Crazy to think \n* U...  ...
# 3       False              Is Twitter just a mixture of experts?  ...
# 4       False  What are the most fundamental unanswered quest...  ...
# ..        ...                                                ...  ...
# 95      False                  Hell yea! https://t.co/A4qSisy7dj  ...
# 96      False  I probably have this thought daily.. when I’m ...  ...
# 97      False  @Randomvoter99 an old question where predictio...  ...
# 98      False  I can't wait until someone reinvents health in...  ...
# 99      False  This whole exercise thing is great if you can ...  ...
#
#                                                  user is_quote_status  \
# 0   {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 1   {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 2   {'blocking': False, 'created_at': 'Fri Jun 10 ...            True
# 3   {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 4   {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# ..                                                ...             ...
# 95  {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 96  {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 97  {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 98  {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
# 99  {'blocking': False, 'created_at': 'Fri Jun 10 ...             NaN
#
#                                         quoted_status  quoted_status_id_str  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2   {'id': 0, 'location': '', 'conversation_id_str...   1649448740753743873
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# ..                                                ...                   ...
# 95                                                NaN                   NaN
# 96                                                NaN                   NaN
# 97                                                NaN                   NaN
# 98                                                NaN                   NaN
# 99                                                NaN                   NaN
#
#                               quoted_status_permalink  in_reply_to_name  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2   {'display': 'twitter.com/Rainmaker1973/…', 'ex...               NaN
# 3                                                 NaN               NaN
# 4                                                 NaN               NaN
# ..                                                ...               ...
# 95                                                NaN               NaN
# 96                                                NaN              rpoo
# 97                                                NaN     Randomvoter99
# 98                                                NaN               NaN
# 99                                                NaN               NaN
#
#     in_reply_to_screen_name  in_reply_to_status_id_str  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
# ..                      ...                        ...
# 95                      NaN                        NaN
# 96                     rpoo        1682043848309211137
# 97            Randomvoter99        1652392379566129155
# 98                      NaN                        NaN
# 99                      NaN                        NaN
#
#    in_reply_to_user_id_str card
# 0                      NaN  NaN
# 1                      NaN  NaN
# 2                      NaN  NaN
# 3                      NaN  NaN
# 4                      NaN  NaN
# ..                     ...  ...
# 95                     NaN  NaN
# 96               314341900  NaN
# 97              1936176655  NaN
# 98                     NaN  NaN
# 99                     NaN  NaN
#
# [100 rows x 29 columns]

# %%
df.to_csv("rapoo.csv",index=False)
